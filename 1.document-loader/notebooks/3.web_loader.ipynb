# %%
from langchain_community.document_loaders import WebBaseLoader
from pprint import pp

url_1 = "https://docs.langchain.com/"
url_2 = "https://docs.langchain.com/langsmith/platform-setup"
loader = WebBaseLoader(web_path=[url_1, url_2])
documents = loader.load()
# len(documents)
# documents[1].page_content
pp(documents[1].metadata)
# Out:
# {'source': 'https://docs.langchain.com/langsmith/platform-setup',
#  'title': 'Set up LangSmith - Docs by LangChain',
#  'description': 'Host and manage LangSmith infrastructure for observability, '
#                 'evaluation, and prompt engineering.',
#  'language': 'en'}

# %% [markdown]
# ## Recursive Loader

# %%
from langchain_community.document_loaders import RecursiveUrlLoader
from bs4 import BeautifulSoup
from pprint import pp

url = "https://docs.langchain.com/langsmith/platform-setup"

loader = RecursiveUrlLoader(
    url=url,
    max_depth=2,
    # extractor=lambda x: BeautifulSoup(x, "html.parser").get_text()
)

documents = loader.load()
# print("Number of documents:", len(documents))
# pp(documents[0])

for i in range (10):
    doc = documents[i]
    print(doc.metadata, end="\n\n")
# Out:
# {'source': 'https://docs.langchain.com/langsmith/platform-setup', 'content_type': 'text/html; charset=utf-8', 'title': 'Set up LangSmith - Docs by LangChain', 'description': 'Host and manage LangSmith infrastructure for observability, evaluation, and prompt engineering.', 'language': 'en'}
#
# {'source': 'https://docs.langchain.com/llms.txt', 'content_type': 'text/plain; charset=utf-8'}
#
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/chunks/84b99a46231ef6be.js?dpl=dpl_Ao9GqH6q1DfWvDpNkKsUzxH61T5C', 'content_type': 'application/javascript; charset=utf-8'}
#
# {'source': 'https://docs.langchain.com/langsmith/admin', 'content_type': 'text/html; charset=utf-8', 'title': 'Account - Docs by LangChain', 'description': 'Set up your LangSmith account, including API keys, profile configuration, integrations, and pricing tiers.', 'language': 'en'}
#
# ...

# %%
# lazy load
from langchain_community.document_loaders import RecursiveUrlLoader
from bs4 import BeautifulSoup
from pprint import pp

url = "https://docs.langchain.com/langsmith/platform-setup"

loader = RecursiveUrlLoader(
    url=url,
    max_depth=2,
)

documents = loader.lazy_load()

counter = 0
for doc in documents:
    if counter == 10:
        break

    counter = counter+1
    print(doc.page_content)
    print(doc.metadata)
# Out:
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify-assets/_next/static/media/83afe278b6a6bb3c.p.3a6ba036.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/mintlify-assets/_next/static/media/PaperMono_Variable.p.aa32f7a0.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/mintlify-assets/_next/static/media/f67ad414ed34149c.p.84166d94.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" as="image" href="https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&amp;auto=format&amp;n=nQm-sjd_MByLhgeW&amp;q=85&amp;s=5babf1a1962208fd7eed942fa243
# ...
